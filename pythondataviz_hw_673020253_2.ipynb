# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanaphon-673020253-2/PythonDataViz2026/blob/main/pythondataviz_hw_673020253_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hw3

# %% [markdown]
# ## HW คำนวณเวลาเป็นวินาทีของเวลาต่อไปนี้โดยใช้คำสั่ง split() ช่วย (print ออกมาให้สวยงาม)
# 12:30:15
#
# 13:41:07
#
# 12:53:15
#
# 00:59:25
#
# 11:11:11
#
# 16:06:09

# %%
print("=============================================================")
time = '12:30:15'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")

print("=============================================================")
time = '13:41:07'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")
print("=============================================================")

time = '12:53:15'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")
print("=============================================================")
time = '00:59:25'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")
print("=============================================================")
time = '11:11:11'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")
print("=============================================================")
time = '16:06:09'
t = time.split(':')
h = int(t[0])
m = int(t[1])
se = int(t[2])
total_se = (h * 3600) + (m * 60) + se
print(f"เวลา {time} คิดเป็น {total_se:,} วินาที")
print("=============================================================")
# Out:
# ...
# เวลา 12:30:15 คิดเป็น 45,015 วินาที
# ...
# เวลา 13:41:07 คิดเป็น 49,267 วินาที
# ...
# เวลา 12:53:15 คิดเป็น 46,395 วินาที
# ...
# เวลา 00:59:25 คิดเป็น 3,565 วินาที
# ...
# เวลา 11:11:11 คิดเป็น 40,271 วินาที
# ...
# เวลา 16:06:09 คิดเป็น 57,969 วินาที
# ...

# %% [markdown]
# ## ให้สร้างฟังก์ชั่นคำนวณเวลาเป็นวินาทีของเวลาใดๆ และ print ออกมาให้สวยงาม

# %%
def counting_seconds(time):
    t = time.split(':')
    h = int(t[0])
    m = int(t[1])
    se = int(t[2])
    total_second = (h * 3600) + (m * 60) + se
    print(f"เวลา {time} ชั่วโมง คิดเป็น {total_second:,} วินาที")

# %% [markdown]
# ## ให้ สร้าง list ของ เวลา ```['12:30:15','13:41:07',....]``` แล้ววนลูปเรียกฟังก์ชั่นคำนวณเวลาเป็น วินาที
#
# **commit ว่า HW3**

# %%
time_list = [
    "12:30:15",
    "13:41:07",
    "12:53:15",
    "00:59:25",
    "11:11:11",
    "16:06:09"]

# %%
print(f'<-------แปลงเวลา(ชั่วโมง) เป็นวินาที------->')
for i in time_list:
    counting_seconds(i)
# Out:
# <-------แปลงเวลา(ชั่วโมง) เป็นวินาที------->
# เวลา 12:30:15 ชั่วโมง คิดเป็น 45,015 วินาที
# เวลา 13:41:07 ชั่วโมง คิดเป็น 49,267 วินาที
# เวลา 12:53:15 ชั่วโมง คิดเป็น 46,395 วินาที
# เวลา 00:59:25 ชั่วโมง คิดเป็น 3,565 วินาที
# เวลา 11:11:11 ชั่วโมง คิดเป็น 40,271 วินาที
# เวลา 16:06:09 ชั่วโมง คิดเป็น 57,969 วินาที

# %% [markdown]
# #Hw4

# %% [markdown]
# ## HW
# #### เขียน function ตัดเกรด โดยที่ input เป็นคะแนน(0-100) , output เป็นเกรด (F-A)
# #### วนลูปตัดเกรด input = [1,50,65,90,101,-5,49]

# %% [markdown]
# ##### กำหนด
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ  0  แต่น้อยกว่า 50 จะได้เกรด F
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 50 แต่น้อยกว่า 55 จะได้เกรด D
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 55 แต่น้อยกว่า 60 จะได้เกรด D+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 60 แต่น้อยกว่า 65 จะได้เกรด C
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 65 แต่น้อยกว่า 70 จะได้เกรด C+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 70 แต่น้อยกว่า 75 จะได้เกรด B
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 75 แต่น้อยกว่า 80 จะได้เกรด B+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 80  จะได้เกรด A
#       แต่ว่าค่าคะแนนจะต้องไม่ต่ำกว่า 0 และมากกว่า 100 ไม่งั้นจะเกิด error

# %%
def grade(score):
    if score > 100:
        return "Error"
    elif score < 0:
        return "Error"
    elif score >= 80:
        return "A"
    elif score >=75:
        return "B+"
    elif score >= 70:
        return "B"
    elif score >= 60:
        return "C+"
    elif score >= 60:
        return "C"
    elif score >= 55:
        return "D+"
    elif score >= 50:
        return "D"
    else:
        return "F"

# %%
score_list = [1,50,65,90,101,-5,49]

# %%
for i in score_list:
    if 0 <= i <= 100:
        score_grade = grade(i)
        print(f"คะแนนคุณคือ {i} คุณได้เกรด {score_grade}")
    else:
        print(f"คะแนนคุณคือ {i} ไม่ถูกต้อง")
# Out:
# คะแนนคุณคือ 1 คุณได้เกรด F
# คะแนนคุณคือ 50 คุณได้เกรด D
# คะแนนคุณคือ 65 คุณได้เกรด C+
# คะแนนคุณคือ 90 คุณได้เกรด A
# คะแนนคุณคือ 101 ไม่ถูกต้อง
# คะแนนคุณคือ -5 ไม่ถูกต้อง
# คะแนนคุณคือ 49 คุณได้เกรด F

# %% [markdown]
# #Hw5

# %% [markdown]
# เขียน function คูณ matrix
#
# แล้ว test กับ matrix ขนาด (2,3) * (3,2), (4,4) * (4,1), (2,2) * (2,2)

# %%
import numpy as np

# %%
def matric_multi(A,B):
    m = len(A)          # จำนวนแถว A
    a = len(A[0])     # จำนวนหลัก A
    b = len(B)        # จำนวนแถว B
    n = len(B[0])       # จำนวนหลัก B
    C = np.zeros((m,n))
    for i in range(m):
        for j in range(n):
            for sum in range(a):
                C[i,j] = C[i,j] + A[i,sum] * B[sum,j]
    return C

# %%
A = np.array([[14, 12, 13],[18, 15, 13]]) # ตัวอย่างชุดตัวเลข
B = np.array([[17, 19],[14, 12],[16, 17]])
matric_multi(A, B)
# Out:
# array([[614., 631.],
#        [724., 743.]])

# %%
A = np.array([[4, 5, 7, 14],[12, 3, 14, 9],[3, 6, 11, 17],[11, 8, 5, 16]]) # ตัวอย่างชุดตัวเลข
B = np.array([[2],[4],[6],[8]])
matric_multi(A, B)
# Out:
# array([[182.],
#        [192.],
#        [232.],
#        [212.]])

# %%
A = np.array([[4, 16],[11, 24]]) # ตัวอย่างชุดตัวเลข
B = np.array([[7, 8],[9, 47]])
matric_multi(A, B)
# Out:
# array([[ 172.,  784.],
#        [ 293., 1216.]])

# %% [markdown]
# #Hw6

# %% [markdown]
# ##HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/DataVz/confirmed-cases.csv")
# Out:
# /tmp/ipykernel_1826/2868352268.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/DataVz/confirmed-cases.csv")

# %% [markdown]
# ##1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด

# %%
df.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
# 2             เมือง
# 3               NaN
# ...

# %%
df.columns
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset'],
#       dtype='object')

# %%
df= df.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_isolation':'ไม่รู้', 'nationality':'ไม่รู้', 'district_of_onset': 'ไม่รู้', 'Notified date': '-', 'Unit': 'ปี'})

# %%
male = df[df['sex'] == 'ชาย'][['sex','age','province_of_isolation']]
female = df[df['sex'] == 'หญิง'][['sex','age','province_of_isolation']]
male.head()
female.head()
# Out:
#     sex   age province_of_isolation
# 0  หญิง  61.0         กรุงเทพมหานคร
# 1  หญิง  74.0         กรุงเทพมหานคร
# 2  หญิง  73.0                นครปฐม
# 4  หญิง  66.0               นนทบุรี
# 5  หญิง  33.0         กรุงเทพมหานคร

# %%
male['age'] = pd.to_numeric(male['age'], errors='coerce')
female['age'] = pd.to_numeric(female['age'], errors='coerce')

# %%
print(male['age'].mean())
print(female['age'].mean())
# Out:
# 34.96292702130938
# 36.16090881617699

# %% [markdown]
# OR

# %%
sum = 0
N = 0
for i in male['age']:
  if i > -1:
    sum = sum + i
    N = N + 1
print(sum/N)
# Out:
# 34.962927021309376

# %%
sum = 0
N = 0
for i in female['age']:
  if i > 0:
    sum = sum + i
    N = N + 1
print(sum/N)
# Out:
# 36.16090881617699

# %% [markdown]
# ## 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %%
print(male.head())
female.head()
# Out:
#     sex   age province_of_isolation
# 3   ชาย  68.0         กรุงเทพมหานคร
# 8   ชาย  63.0         กรุงเทพมหานคร
# 10  ชาย  33.0         กรุงเทพมหานคร
# 11  ชาย  61.0         กรุงเทพมหานคร
# 12  ชาย   6.0         กรุงเทพมหานคร
#     sex   age province_of_isolation
# 0  หญิง  61.0         กรุงเทพมหานคร
# 1  หญิง  74.0         กรุงเทพมหานคร
# 2  หญิง  73.0                นครปฐม
# 4  หญิง  66.0               นนทบุรี
# 5  หญิง  33.0         กรุงเทพมหานคร

# %%
male[male['province_of_isolation'] == "ขอนแก่น"]['age'].mean()
# Out:
# np.float64(34.88742916022669)

# %%
female[female['province_of_isolation'] == "ขอนแก่น"]['age'].mean()
# Out:
# np.float64(34.54574132492114)

# %% [markdown]
# Or

# %%
sum = 0
N = 0
for i in male[male['province_of_isolation'] == "ขอนแก่น"]['age']:
  if i > 0:
    sum = sum + i
    N = N + 1
print(sum/N)
# Out:
# 34.88742916022669

# %%
sum = 0
N = 0
for i in female[female['province_of_isolation'] == "ขอนแก่น"]['age']:
  if i > 0:
    sum = sum + i
    N = N + 1
print(sum/N)
# Out:
# 34.54574132492114

# %% [markdown]
# ## 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
df.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020             -  หญิง  61.0   ปี       China
# 1    2     17/1/2020             -  หญิง  74.0   ปี       China
# 2    3     22/1/2020             -  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020             -   ชาย  68.0   ปี       China
# 4    5     24/1/2020             -  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0            ไม่รู้
# 1            ไม่รู้
# 2             เมือง
# 3            ไม่รู้
# ...

# %%
len(df[df['nationality'] != "Thailand"])
# Out:
# 188260

# %% [markdown]
# #Hw7

# %% [markdown]
# ##สร้างตารางใหม่ ที่ค่าใน ```sex``` เป็น missing ทั้งหมด
# * สรุปว่าทำไม record นั้นๆถึงเป็น missing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/DataVz/confirmed-cases.csv")
# Out:
# /tmp/ipykernel_1826/2868352268.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/DataVz/confirmed-cases.csv")

# %%
sex_miss = df[df['sex'].isna()]

# %%
sex_miss.head()
# Out:
#        No. announce_date Notified date  sex  age Unit nationality  \
# 4397  4398    20/12/2020           NaN  NaN  NaN  NaN       Burma
# 4398  4399    20/12/2020           NaN  NaN  NaN  NaN       Burma
# 4399  4400    20/12/2020           NaN  NaN  NaN  NaN       Burma
# 4400  4401    20/12/2020           NaN  NaN  NaN  NaN       Burma
# 4401  4402    20/12/2020           NaN  NaN  NaN  NaN       Burma
#
#      province_of_isolation               risk province_of_onset  \
# 4397             สมุทรสาคร  Cluster สมุทรสาคร         สมุทรสาคร
# 4398             สมุทรสาคร  Cluster สมุทรสาคร         สมุทรสาคร
# 4399             สมุทรสาคร  Cluster สมุทรสาคร         สมุทรสาคร
# 4400             สมุทรสาคร  Cluster สมุทรสาคร         สมุทรสาคร
# 4401             สมุทรสาคร  Cluster สมุทรสาคร         สมุทรสาคร
#
#      district_of_onset
# 4397             เมือง
# 4398             เมือง
# 4399             เมือง
# 4400             เมือง
# 4401             เมือง

# %% [markdown]
# สรุป น่าจะเกิดจากการเก็บข้อมูลไม่ครบถ่วน กรอบข้อมูลไม่ครบ
